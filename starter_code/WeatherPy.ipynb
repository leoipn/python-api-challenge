# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 647

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
new_cities = []
lat        = []
lng        = []
max_temp   = []
humidity   = []
cloudiness = []
wind_speed = []
country    = []
date       = []

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"

print("Beginning Data Retrieval")
print("-----------------------------")

# Loop to call the weather api using a list of cities
for count, city_name in enumerate(cities, start=1):
    query_params = f"q={city_name}&appid={weather_api_key}&units=imperial"
    response = requests.get(base_url + query_params).json()
    
    if (response["cod"]=="404"):
        print("City not found. Skipping...")
    else    :
        new_cities.append(city_name)
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])

    print(f"Processing Record {count} of Set 1 | {city_name}")
        
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saskylakh
# Processing Record 2 of Set 1 | loukhi
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | butaritari
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | ruwi
# City not found. Skipping...
# Processing Record 7 of Set 1 | nizhneyansk
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | sorland
# Processing Record 12 of Set 1 | lebu
# Processing Record 13 of Set 1 | talas
# City not found. Skipping...
# Processing Record 14 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | attawapiskat
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | oneonta
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | carnarvon
# Processing Record 21 of Set 1 | sitka
# City not found. Skipping...
# Processing Record 22 of Set 1 | samusu
# Processing Record 23 of Set 1 | alofi
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | port alfred
# Processing Record 28 of Set 1 | mercedes
# Processing Record 29 of Set 1 | bengkulu
# Processing Record 30 of Set 1 | almeirim
# Processing Record 31 of Set 1 | erenhot
# Processing Record 32 of Set 1 | naze
# Processing Record 33 of Set 1 | taman
# Processing Record 34 of Set 1 | santa cruz
# Processing Record 35 of Set 1 | provideniya
# Processing Record 36 of Set 1 | hambantota
# Processing Record 37 of Set 1 | ancud
# Processing Record 38 of Set 1 | la rioja
# Processing Record 39 of Set 1 | hobbs
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | chern
# Processing Record 42 of Set 1 | vaini
# City not found. Skipping...
# Processing Record 43 of Set 1 | barentsburg
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | sobolevo
# Processing Record 46 of Set 1 | azare
# Processing Record 47 of Set 1 | bilma
# Processing Record 48 of Set 1 | moa
# City not found. Skipping...
# Processing Record 49 of Set 1 | falealupo
# Processing Record 50 of Set 1 | kununurra
# Processing Record 51 of Set 1 | debre tabor
# Processing Record 52 of Set 1 | port moresby
# Processing Record 53 of Set 1 | fortuna
# Processing Record 54 of Set 1 | cape town
# City not found. Skipping...
# Processing Record 55 of Set 1 | kamenskoye
# Processing Record 56 of Set 1 | ribeira grande
# City not found. Skipping...
# Processing Record 57 of Set 1 | illoqqortoormiut
# Processing Record 58 of Set 1 | liwale
# Processing Record 59 of Set 1 | parabel
# Processing Record 60 of Set 1 | albany
# Processing Record 61 of Set 1 | victoria
# Processing Record 62 of Set 1 | sungaipenuh
# Processing Record 63 of Set 1 | nishihara
# Processing Record 64 of Set 1 | qinhuangdao
# Processing Record 65 of Set 1 | bucerias
# Processing Record 66 of Set 1 | jamestown
# Processing Record 67 of Set 1 | nalut
# Processing Record 68 of Set 1 | byron bay
# Processing Record 69 of Set 1 | kyra
# Processing Record 70 of Set 1 | kapaa
# Processing Record 71 of Set 1 | tuktoyaktuk
# Processing Record 72 of Set 1 | chokurdakh
# Processing Record 73 of Set 1 | grand baie
# Processing Record 74 of Set 1 | doka
# Processing Record 75 of Set 1 | ilulissat
# Processing Record 76 of Set 1 | kavieng
# Processing Record 77 of Set 1 | paita
# Processing Record 78 of Set 1 | georgetown
# Processing Record 79 of Set 1 | dabwali
# Processing Record 80 of Set 1 | puerto del rosario
# Processing Record 81 of Set 1 | clyde river
# Processing Record 82 of Set 1 | yar-sale
# Processing Record 83 of Set 1 | ilhabela
# Processing Record 84 of Set 1 | jining
# Processing Record 85 of Set 1 | kota
# Processing Record 86 of Set 1 | komsomolskiy
# City not found. Skipping...
# Processing Record 87 of Set 1 | alotau
# Processing Record 88 of Set 1 | fredericksburg
# Processing Record 89 of Set 1 | roswell
# Processing Record 90 of Set 1 | troitsko-pechorsk
# City not found. Skipping...
# Processing Record 91 of Set 1 | gorno-chuyskiy
# Processing Record 92 of Set 1 | comodoro rivadavia
# Processing Record 93 of Set 1 | yellowknife
# Processing Record 94 of Set 1 | hithadhoo
# Processing Record 95 of Set 1 | belmonte
# Processing Record 96 of Set 1 | hoquiam
# Processing Record 97 of Set 1 | guerrero negro
# Processing Record 98 of Set 1 | atuona
# Processing Record 99 of Set 1 | chuy
# Processing Record 100 of Set 1 | chapais
# Processing Record 101 of Set 1 | kodiak
# Processing Record 102 of Set 1 | hobart
# Processing Record 103 of Set 1 | fushun
# Processing Record 104 of Set 1 | fecamp
# Processing Record 105 of Set 1 | dikson
# Processing Record 106 of Set 1 | cayenne
# Processing Record 107 of Set 1 | buraydah
# City not found. Skipping...
# Processing Record 108 of Set 1 | utiroa
# Processing Record 109 of Set 1 | norman wells
# Processing Record 110 of Set 1 | skibbereen
# Processing Record 111 of Set 1 | longyearbyen
# Processing Record 112 of Set 1 | belyy yar
# Processing Record 113 of Set 1 | yerbogachen
# Processing Record 114 of Set 1 | zachepylivka
# Processing Record 115 of Set 1 | vardo
# City not found. Skipping...
# Processing Record 116 of Set 1 | falkoping
# Processing Record 117 of Set 1 | khatanga
# City not found. Skipping...
# Processing Record 118 of Set 1 | belushya guba
# Processing Record 119 of Set 1 | husavik
# Processing Record 120 of Set 1 | abdanan
# Processing Record 121 of Set 1 | airai
# Processing Record 122 of Set 1 | vestmannaeyjar
# Processing Record 123 of Set 1 | sayyan
# Processing Record 124 of Set 1 | mar del plata
# Processing Record 125 of Set 1 | stralsund
# Processing Record 126 of Set 1 | misratah
# Processing Record 127 of Set 1 | eydhafushi
# Processing Record 128 of Set 1 | zhangye
# Processing Record 129 of Set 1 | koungou
# Processing Record 130 of Set 1 | port hedland
# Processing Record 131 of Set 1 | hermanus
# Processing Record 132 of Set 1 | ghanzi
# Processing Record 133 of Set 1 | leh
# Processing Record 134 of Set 1 | san patricio
# Processing Record 135 of Set 1 | feodosiya
# Processing Record 136 of Set 1 | yining
# Processing Record 137 of Set 1 | richards bay
# City not found. Skipping...
# Processing Record 138 of Set 1 | hihifo
# Processing Record 139 of Set 1 | macrohon
# City not found. Skipping...
# Processing Record 140 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 141 of Set 1 | amderma
# Processing Record 142 of Set 1 | kalamata
# Processing Record 143 of Set 1 | san fernando
# Processing Record 144 of Set 1 | tiksi
# Processing Record 145 of Set 1 | inirida
# Processing Record 146 of Set 1 | sarangani
# Processing Record 147 of Set 1 | zhigansk
# Processing Record 148 of Set 1 | nikolskoye
# Processing Record 149 of Set 1 | aksarka
# Processing Record 150 of Set 1 | eha amufu
# Processing Record 151 of Set 1 | leningradskiy
# Processing Record 152 of Set 1 | clovis
# Processing Record 153 of Set 1 | port hardy
# Processing Record 154 of Set 1 | poltavka
# City not found. Skipping...
# Processing Record 155 of Set 1 | babanusah
# Processing Record 156 of Set 1 | gympie
# Processing Record 157 of Set 1 | nantucket
# Processing Record 158 of Set 1 | ondjiva
# Processing Record 159 of Set 1 | basco
# Processing Record 160 of Set 1 | catende
# Processing Record 161 of Set 1 | bairiki
# Processing Record 162 of Set 1 | bredasdorp
# Processing Record 163 of Set 1 | liepaja
# Processing Record 164 of Set 1 | puerto ayora
# Processing Record 165 of Set 1 | namatanai
# Processing Record 166 of Set 1 | port macquarie
# Processing Record 167 of Set 1 | quiroga
# Processing Record 168 of Set 1 | sao joao da barra
# Processing Record 169 of Set 1 | flin flon
# City not found. Skipping...
# Processing Record 170 of Set 1 | ijaki
# Processing Record 171 of Set 1 | pisco
# Processing Record 172 of Set 1 | saint george
# Processing Record 173 of Set 1 | kardamaina
# Processing Record 174 of Set 1 | isangel
# Processing Record 175 of Set 1 | kolyshley
# Processing Record 176 of Set 1 | atar
# Processing Record 177 of Set 1 | halifax
# City not found. Skipping...
# Processing Record 178 of Set 1 | hunza
# Processing Record 179 of Set 1 | hazorasp
# Processing Record 180 of Set 1 | lagoa
# Processing Record 181 of Set 1 | aklavik
# Processing Record 182 of Set 1 | vila velha
# Processing Record 183 of Set 1 | esperance
# Processing Record 184 of Set 1 | liverpool
# Processing Record 185 of Set 1 | eyl
# City not found. Skipping...
# Processing Record 186 of Set 1 | sumbawa
# City not found. Skipping...
# Processing Record 187 of Set 1 | lalomanu
# Processing Record 188 of Set 1 | tasiilaq
# Processing Record 189 of Set 1 | lavrentiya
# Processing Record 190 of Set 1 | saint-philippe
# Processing Record 191 of Set 1 | bethel
# Processing Record 192 of Set 1 | tigil
# Processing Record 193 of Set 1 | molo
# Processing Record 194 of Set 1 | hilo
# Processing Record 195 of Set 1 | souillac
# Processing Record 196 of Set 1 | bah
# City not found. Skipping...
# Processing Record 197 of Set 1 | sentyabrskiy
# Processing Record 198 of Set 1 | asmar
# Processing Record 199 of Set 1 | severo-kurilsk
# Processing Record 200 of Set 1 | southbridge
# City not found. Skipping...
# Processing Record 201 of Set 1 | bur gabo
# Processing Record 202 of Set 1 | hami
# Processing Record 203 of Set 1 | diamantina
# Processing Record 204 of Set 1 | sumenep
# Processing Record 205 of Set 1 | teodoro sampaio
# Processing Record 206 of Set 1 | torbay
# Processing Record 207 of Set 1 | axim
# Processing Record 208 of Set 1 | pascagoula
# Processing Record 209 of Set 1 | pacific grove
# Processing Record 210 of Set 1 | matay
# Processing Record 211 of Set 1 | shache
# Processing Record 212 of Set 1 | kayerkan
# Processing Record 213 of Set 1 | hasaki
# Processing Record 214 of Set 1 | akdepe
# Processing Record 215 of Set 1 | maceio
# Processing Record 216 of Set 1 | imbituba
# Processing Record 217 of Set 1 | tual
# Processing Record 218 of Set 1 | santa marta
# Processing Record 219 of Set 1 | nome
# Processing Record 220 of Set 1 | narsaq
# Processing Record 221 of Set 1 | tucuman
# Processing Record 222 of Set 1 | burnie
# Processing Record 223 of Set 1 | mabaruma
# Processing Record 224 of Set 1 | sibolga
# City not found. Skipping...
# Processing Record 225 of Set 1 | maloshuyka
# Processing Record 226 of Set 1 | mattru
# Processing Record 227 of Set 1 | bud
# Processing Record 228 of Set 1 | kailua
# City not found. Skipping...
# Processing Record 229 of Set 1 | palabuhanratu
# Processing Record 230 of Set 1 | arraial do cabo
# Processing Record 231 of Set 1 | sampit
# Processing Record 232 of Set 1 | paderno dugnano
# Processing Record 233 of Set 1 | cidreira
# Processing Record 234 of Set 1 | sabang
# Processing Record 235 of Set 1 | diapaga
# Processing Record 236 of Set 1 | bac lieu
# City not found. Skipping...
# Processing Record 237 of Set 1 | rungata
# Processing Record 238 of Set 1 | garissa
# Processing Record 239 of Set 1 | daru
# Processing Record 240 of Set 1 | cockburn town
# Processing Record 241 of Set 1 | yaan
# City not found. Skipping...
# Processing Record 242 of Set 1 | dera din panah
# Processing Record 243 of Set 1 | ishigaki
# Processing Record 244 of Set 1 | lukovetskiy
# Processing Record 245 of Set 1 | prince rupert
# Processing Record 246 of Set 1 | whitehaven
# Processing Record 247 of Set 1 | faya
# Processing Record 248 of Set 1 | larsnes
# Processing Record 249 of Set 1 | brigantine
# Processing Record 250 of Set 1 | cap malheureux
# Processing Record 251 of Set 1 | kushima
# Processing Record 252 of Set 1 | kalevala
# Processing Record 253 of Set 1 | pevek
# Processing Record 254 of Set 1 | imeni poliny osipenko
# Processing Record 255 of Set 1 | lompoc
# Processing Record 256 of Set 1 | abalak
# Processing Record 257 of Set 1 | east london
# Processing Record 258 of Set 1 | embonas
# Processing Record 259 of Set 1 | vostok
# Processing Record 260 of Set 1 | bambous virieux
# Processing Record 261 of Set 1 | cuauhtemoc
# Processing Record 262 of Set 1 | baruun-urt
# Processing Record 263 of Set 1 | whitianga
# Processing Record 264 of Set 1 | nemuro
# Processing Record 265 of Set 1 | taree
# Processing Record 266 of Set 1 | mendeleyevo
# Processing Record 267 of Set 1 | geraldton
# Processing Record 268 of Set 1 | broome
# Processing Record 269 of Set 1 | aykhal
# Processing Record 270 of Set 1 | shirokiy
# Processing Record 271 of Set 1 | malindi
# Processing Record 272 of Set 1 | coquimbo
# Processing Record 273 of Set 1 | robertsport
# Processing Record 274 of Set 1 | kismayo
# Processing Record 275 of Set 1 | lasa
# Processing Record 276 of Set 1 | mogadishu
# Processing Record 277 of Set 1 | cabo san lucas
# Processing Record 278 of Set 1 | trairi
# Processing Record 279 of Set 1 | chute-aux-outardes
# Processing Record 280 of Set 1 | castro
# Processing Record 281 of Set 1 | siilinjarvi
# City not found. Skipping...
# Processing Record 282 of Set 1 | tumannyy
# Processing Record 283 of Set 1 | businga
# Processing Record 284 of Set 1 | dandong
# Processing Record 285 of Set 1 | sao filipe
# City not found. Skipping...
# Processing Record 286 of Set 1 | umzimvubu
# Processing Record 287 of Set 1 | flinders
# Processing Record 288 of Set 1 | tura
# Processing Record 289 of Set 1 | dali
# City not found. Skipping...
# Processing Record 290 of Set 1 | uwayl
# Processing Record 291 of Set 1 | gewane
# Processing Record 292 of Set 1 | vila franca do campo
# Processing Record 293 of Set 1 | coahuayana
# Processing Record 294 of Set 1 | kaitangata
# Processing Record 295 of Set 1 | qujing
# Processing Record 296 of Set 1 | oksfjord
# Processing Record 297 of Set 1 | tecoanapa
# Processing Record 298 of Set 1 | rocha
# Processing Record 299 of Set 1 | gazanjyk
# Processing Record 300 of Set 1 | padang
# City not found. Skipping...
# Processing Record 301 of Set 1 | vaitupu
# Processing Record 302 of Set 1 | lovosice
# City not found. Skipping...
# Processing Record 303 of Set 1 | arkhangelos
# Processing Record 304 of Set 1 | parakou
# Processing Record 305 of Set 1 | katete
# Processing Record 306 of Set 1 | uray
# Processing Record 307 of Set 1 | hofn
# Processing Record 308 of Set 1 | buala
# Processing Record 309 of Set 1 | dalby
# Processing Record 310 of Set 1 | deputatskiy
# Processing Record 311 of Set 1 | ilek
# Processing Record 312 of Set 1 | beloha
# Processing Record 313 of Set 1 | asau
# Processing Record 314 of Set 1 | ketchikan
# Processing Record 315 of Set 1 | oranjestad
# Processing Record 316 of Set 1 | antalaha
# Processing Record 317 of Set 1 | moerbeke
# Processing Record 318 of Set 1 | manta
# Processing Record 319 of Set 1 | waipawa
# Processing Record 320 of Set 1 | linkoping
# Processing Record 321 of Set 1 | carutapera
# Processing Record 322 of Set 1 | newport
# Processing Record 323 of Set 1 | havre-saint-pierre
# City not found. Skipping...
# Processing Record 324 of Set 1 | uskedal
# Processing Record 325 of Set 1 | ler
# Processing Record 326 of Set 1 | necochea
# Processing Record 327 of Set 1 | port-cartier
# Processing Record 328 of Set 1 | sikasso
# Processing Record 329 of Set 1 | manokwari
# Processing Record 330 of Set 1 | harper
# Processing Record 331 of Set 1 | merano
# Processing Record 332 of Set 1 | santa fe
# Processing Record 333 of Set 1 | oriximina
# Processing Record 334 of Set 1 | xining
# Processing Record 335 of Set 1 | svetlogorsk
# Processing Record 336 of Set 1 | wanning
# Processing Record 337 of Set 1 | mount gambier
# Processing Record 338 of Set 1 | bandarbeyla
# Processing Record 339 of Set 1 | sumbe
# Processing Record 340 of Set 1 | luderitz
# Processing Record 341 of Set 1 | mareeba
# Processing Record 342 of Set 1 | port blair
# Processing Record 343 of Set 1 | kieta
# Processing Record 344 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 345 of Set 1 | sharan
# Processing Record 346 of Set 1 | ambilobe
# Processing Record 347 of Set 1 | hastings
# Processing Record 348 of Set 1 | itaituba
# City not found. Skipping...
# Processing Record 349 of Set 1 | nguiu
# Processing Record 350 of Set 1 | lazaro cardenas
# Processing Record 351 of Set 1 | kalmunai
# Processing Record 352 of Set 1 | constitucion
# Processing Record 353 of Set 1 | slave lake
# Processing Record 354 of Set 1 | keskin
# Processing Record 355 of Set 1 | pirai
# Processing Record 356 of Set 1 | saint-joseph
# Processing Record 357 of Set 1 | veryi
# Processing Record 358 of Set 1 | el estor
# Processing Record 359 of Set 1 | kirovskiy
# Processing Record 360 of Set 1 | bonthe
# Processing Record 361 of Set 1 | san jeronimo
# Processing Record 362 of Set 1 | codrington
# Processing Record 363 of Set 1 | nabire
# Processing Record 364 of Set 1 | montanha
# Processing Record 365 of Set 1 | ekhabi
# Processing Record 366 of Set 1 | kuytun
# Processing Record 367 of Set 1 | lorengau
# Processing Record 368 of Set 1 | egvekinot
# Processing Record 369 of Set 1 | bathsheba
# City not found. Skipping...
# Processing Record 370 of Set 1 | kadykchan
# Processing Record 371 of Set 1 | iqaluit
# Processing Record 372 of Set 1 | greenville
# Processing Record 373 of Set 1 | ciechanow
# Processing Record 374 of Set 1 | amberley
# Processing Record 375 of Set 1 | omboue
# Processing Record 376 of Set 1 | puerto gaitan
# Processing Record 377 of Set 1 | ucluelet
# Processing Record 378 of Set 1 | zhezkazgan
# Processing Record 379 of Set 1 | berlevag
# City not found. Skipping...
# Processing Record 380 of Set 1 | saleaula
# Processing Record 381 of Set 1 | krasnoarmeysk
# Processing Record 382 of Set 1 | yumen
# Processing Record 383 of Set 1 | laguna
# Processing Record 384 of Set 1 | carberry
# Processing Record 385 of Set 1 | morondava
# Processing Record 386 of Set 1 | kruisfontein
# Processing Record 387 of Set 1 | bulgan
# Processing Record 388 of Set 1 | santa rosa
# Processing Record 389 of Set 1 | sao francisco de paula
# Processing Record 390 of Set 1 | vrangel
# City not found. Skipping...
# Processing Record 391 of Set 1 | valjala
# Processing Record 392 of Set 1 | sulangan
# Processing Record 393 of Set 1 | wukari
# Processing Record 394 of Set 1 | gamba
# Processing Record 395 of Set 1 | camacha
# Processing Record 396 of Set 1 | kungurtug
# Processing Record 397 of Set 1 | lagos
# Processing Record 398 of Set 1 | porangatu
# Processing Record 399 of Set 1 | marawi
# Processing Record 400 of Set 1 | hamilton
# City not found. Skipping...
# Processing Record 401 of Set 1 | marcona
# Processing Record 402 of Set 1 | tessalit
# Processing Record 403 of Set 1 | kelo
# Processing Record 404 of Set 1 | bumba
# Processing Record 405 of Set 1 | balaipungut
# City not found. Skipping...
# Processing Record 406 of Set 1 | geresk
# Processing Record 407 of Set 1 | henties bay
# Processing Record 408 of Set 1 | dubbo
# Processing Record 409 of Set 1 | jalingo
# Processing Record 410 of Set 1 | bukachacha
# Processing Record 411 of Set 1 | nuuk
# Processing Record 412 of Set 1 | taoudenni
# Processing Record 413 of Set 1 | mitsamiouli
# Processing Record 414 of Set 1 | boa vista
# Processing Record 415 of Set 1 | balad
# Processing Record 416 of Set 1 | aksu
# Processing Record 417 of Set 1 | zhangjiakou
# Processing Record 418 of Set 1 | san andres
# Processing Record 419 of Set 1 | lokosovo
# Processing Record 420 of Set 1 | yantzaza
# Processing Record 421 of Set 1 | aquidaba
# Processing Record 422 of Set 1 | itoman
# Processing Record 423 of Set 1 | korla
# Processing Record 424 of Set 1 | tisnov
# Processing Record 425 of Set 1 | chalakudi
# City not found. Skipping...
# Processing Record 426 of Set 1 | aflu
# Processing Record 427 of Set 1 | sambava
# Processing Record 428 of Set 1 | mahebourg
# Processing Record 429 of Set 1 | san quintin
# Processing Record 430 of Set 1 | saint-augustin
# Processing Record 431 of Set 1 | carbonear
# City not found. Skipping...
# Processing Record 432 of Set 1 | mys shmidta
# Processing Record 433 of Set 1 | marrakesh
# Processing Record 434 of Set 1 | beecher
# Processing Record 435 of Set 1 | xai-xai
# Processing Record 436 of Set 1 | touros
# Processing Record 437 of Set 1 | kaeo
# Processing Record 438 of Set 1 | kharsawan
# Processing Record 439 of Set 1 | gallup
# City not found. Skipping...
# Processing Record 440 of Set 1 | juifang
# Processing Record 441 of Set 1 | mumford
# Processing Record 442 of Set 1 | miri
# City not found. Skipping...
# Processing Record 443 of Set 1 | tabiauea
# Processing Record 444 of Set 1 | la ronge
# Processing Record 445 of Set 1 | bubaque
# Processing Record 446 of Set 1 | molina
# City not found. Skipping...
# Processing Record 447 of Set 1 | talesh
# Processing Record 448 of Set 1 | djibo
# Processing Record 449 of Set 1 | upernavik
# Processing Record 450 of Set 1 | rabak
# Processing Record 451 of Set 1 | ponta do sol
# Processing Record 452 of Set 1 | sehithwa
# Processing Record 453 of Set 1 | hovd
# Processing Record 454 of Set 1 | hvolsvollur
# Processing Record 455 of Set 1 | san jose
# Processing Record 456 of Set 1 | neiafu
# Processing Record 457 of Set 1 | nanuque
# City not found. Skipping...
# Processing Record 458 of Set 1 | ust-kamchatsk
# Processing Record 459 of Set 1 | huarmey
# Processing Record 460 of Set 1 | daniel flores
# Processing Record 461 of Set 1 | empalme
# Processing Record 462 of Set 1 | saldanha
# Processing Record 463 of Set 1 | berdsk
# Processing Record 464 of Set 1 | marakkanam
# Processing Record 465 of Set 1 | izhma
# Processing Record 466 of Set 1 | fairbanks
# Processing Record 467 of Set 1 | niono
# Processing Record 468 of Set 1 | arkhipo-osipovka
# Processing Record 469 of Set 1 | muros
# Processing Record 470 of Set 1 | umm lajj
# Processing Record 471 of Set 1 | bela
# Processing Record 472 of Set 1 | dingle
# Processing Record 473 of Set 1 | quang ngai
# Processing Record 474 of Set 1 | varhaug
# Processing Record 475 of Set 1 | loa janan
# Processing Record 476 of Set 1 | beyla
# Processing Record 477 of Set 1 | salmas
# Processing Record 478 of Set 1 | bilibino
# City not found. Skipping...
# Processing Record 479 of Set 1 | ndiekro
# Processing Record 480 of Set 1 | sandnessjoen
# Processing Record 481 of Set 1 | the valley
# Processing Record 482 of Set 1 | olinda
# Processing Record 483 of Set 1 | namibe
# Processing Record 484 of Set 1 | ust-kuyga
# Processing Record 485 of Set 1 | gasa
# Processing Record 486 of Set 1 | christchurch
# City not found. Skipping...
# Processing Record 487 of Set 1 | litoral del san juan
# City not found. Skipping...
# Processing Record 488 of Set 1 | borlange
# Processing Record 489 of Set 1 | kondoa
# Processing Record 490 of Set 1 | weinan
# Processing Record 491 of Set 1 | mikhaylovka
# Processing Record 492 of Set 1 | ballina
# Processing Record 493 of Set 1 | tezu
# Processing Record 494 of Set 1 | iquitos
# Processing Record 495 of Set 1 | kahului
# Processing Record 496 of Set 1 | grindavik
# Processing Record 497 of Set 1 | ryki
# Processing Record 498 of Set 1 | avera
# Processing Record 499 of Set 1 | lipin bor
# Processing Record 500 of Set 1 | jalu
# Processing Record 501 of Set 1 | samarai
# Processing Record 502 of Set 1 | sangar
# Processing Record 503 of Set 1 | opuwo
# City not found. Skipping...
# Processing Record 504 of Set 1 | kinanah
# Processing Record 505 of Set 1 | balikpapan
# Processing Record 506 of Set 1 | tsaratanana
# Processing Record 507 of Set 1 | san cristobal
# Processing Record 508 of Set 1 | mweka
# Processing Record 509 of Set 1 | port lincoln
# Processing Record 510 of Set 1 | zaozerne
# Processing Record 511 of Set 1 | sao paulo de olivenca
# Processing Record 512 of Set 1 | ivaipora
# Processing Record 513 of Set 1 | mount isa
# Processing Record 514 of Set 1 | letlhakane
# Processing Record 515 of Set 1 | churapcha
# Processing Record 516 of Set 1 | guozhen
# Processing Record 517 of Set 1 | tautira
# Processing Record 518 of Set 1 | madison
# Processing Record 519 of Set 1 | mandapam
# Processing Record 520 of Set 1 | skjervoy
# Processing Record 521 of Set 1 | kabansk
# Processing Record 522 of Set 1 | kovdor
# Processing Record 523 of Set 1 | bridlington
# Processing Record 524 of Set 1 | rieti
# Processing Record 525 of Set 1 | huinan
# Processing Record 526 of Set 1 | vila
# Processing Record 527 of Set 1 | waw
# Processing Record 528 of Set 1 | senanga
# Processing Record 529 of Set 1 | kikwit
# Processing Record 530 of Set 1 | raudeberg
# Processing Record 531 of Set 1 | corpus christi
# Processing Record 532 of Set 1 | gillette
# Processing Record 533 of Set 1 | castelo branco
# Processing Record 534 of Set 1 | sorong
# Processing Record 535 of Set 1 | nanortalik
# Processing Record 536 of Set 1 | kupang
# Processing Record 537 of Set 1 | kichera
# Processing Record 538 of Set 1 | svarstad
# Processing Record 539 of Set 1 | le robert
# Processing Record 540 of Set 1 | adrar
# Processing Record 541 of Set 1 | kuznechikha
# Processing Record 542 of Set 1 | kathu
# Processing Record 543 of Set 1 | makakilo city
# Processing Record 544 of Set 1 | salgado
# Processing Record 545 of Set 1 | ust-tsilma
# Processing Record 546 of Set 1 | ahipara
# Processing Record 547 of Set 1 | songjianghe
# Processing Record 548 of Set 1 | sri aman
# Processing Record 549 of Set 1 | tilichiki
# Processing Record 550 of Set 1 | alta floresta
# Processing Record 551 of Set 1 | labuan
# Processing Record 552 of Set 1 | jati
# Processing Record 553 of Set 1 | caravelas
# Processing Record 554 of Set 1 | saint-pierre
# Processing Record 555 of Set 1 | maxixe
# Processing Record 556 of Set 1 | yulara
# Processing Record 557 of Set 1 | tshikapa
# Processing Record 558 of Set 1 | maragogi
# Processing Record 559 of Set 1 | jurm
# Processing Record 560 of Set 1 | batagay
# Processing Record 561 of Set 1 | ginosa
# Processing Record 562 of Set 1 | pangody
# Processing Record 563 of Set 1 | pimentel
# Processing Record 564 of Set 1 | meadow lake
# Processing Record 565 of Set 1 | baiyin
# City not found. Skipping...
# Processing Record 566 of Set 1 | meyungs
# Processing Record 567 of Set 1 | khani
# Processing Record 568 of Set 1 | salinas
# Processing Record 569 of Set 1 | dzerzhinsk
# Processing Record 570 of Set 1 | tungor
# Processing Record 571 of Set 1 | kota bahru
# Processing Record 572 of Set 1 | norfolk
# Processing Record 573 of Set 1 | saint-francois
# Processing Record 574 of Set 1 | ust-uda
# Processing Record 575 of Set 1 | kendari
# Processing Record 576 of Set 1 | tommot
# Processing Record 577 of Set 1 | same
# Processing Record 578 of Set 1 | santa maria da vitoria
# Processing Record 579 of Set 1 | remiremont
# Processing Record 580 of Set 1 | prado
# Processing Record 581 of Set 1 | kommunar
# Processing Record 582 of Set 1 | windhoek
# Processing Record 583 of Set 1 | karratha
# Processing Record 584 of Set 1 | faanui
# Processing Record 585 of Set 1 | beyneu
# Processing Record 586 of Set 1 | lodeynoye pole
# Processing Record 587 of Set 1 | tuatapere
# Processing Record 588 of Set 1 | dicabisagan
# Processing Record 589 of Set 1 | dahra
# Processing Record 590 of Set 1 | cloquet
# Processing Record 591 of Set 1 | salina
# Processing Record 592 of Set 1 | ust-nera
# Processing Record 593 of Set 1 | atambua
# Processing Record 594 of Set 1 | uvat
# Processing Record 595 of Set 1 | san matias
# Processing Record 596 of Set 1 | smithers
# Processing Record 597 of Set 1 | gao
# City not found. Skipping...
# Processing Record 598 of Set 1 | makung
# Processing Record 599 of Set 1 | kargil
# Processing Record 600 of Set 1 | honiara
# Processing Record 601 of Set 1 | los llanos de aridane
# Processing Record 602 of Set 1 | grand-santi
# Processing Record 603 of Set 1 | kemijarvi
# City not found. Skipping...
# Processing Record 604 of Set 1 | marathopolis
# Processing Record 605 of Set 1 | kangalassy
# Processing Record 606 of Set 1 | wamba
# Processing Record 607 of Set 1 | paranaiba
# City not found. Skipping...
# Processing Record 608 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 609 of Set 1 | barbar
# Processing Record 610 of Set 1 | qeshm
# City not found. Skipping...
# Processing Record 611 of Set 1 | halalo
# Processing Record 612 of Set 1 | katihar
# Processing Record 613 of Set 1 | ulagan
# Processing Record 614 of Set 1 | klaksvik
# City not found. Skipping...
# Processing Record 615 of Set 1 | viligili
# Processing Record 616 of Set 1 | constantine
# City not found. Skipping...
# Processing Record 617 of Set 1 | ust-bolsheretsk
# Processing Record 618 of Set 1 | gbarnga
# City not found. Skipping...
# Processing Record 619 of Set 1 | doctor pedro p. pena
# Processing Record 620 of Set 1 | itoigawa
# Processing Record 621 of Set 1 | gat
# City not found. Skipping...
# Processing Record 622 of Set 1 | lar gerd
# City not found. Skipping...
# Processing Record 623 of Set 1 | grand centre
# Processing Record 624 of Set 1 | filadelfia
# City not found. Skipping...
# Processing Record 625 of Set 1 | longlac
# Processing Record 626 of Set 1 | dalbandin
# Processing Record 627 of Set 1 | kachiry
# Processing Record 628 of Set 1 | beringovskiy
# City not found. Skipping...
# Processing Record 629 of Set 1 | mrirt
# Processing Record 630 of Set 1 | balabac
# Processing Record 631 of Set 1 | quatre cocos
# Processing Record 632 of Set 1 | portugalete
# Processing Record 633 of Set 1 | puerto maldonado
# Processing Record 634 of Set 1 | kalengwa
# Processing Record 635 of Set 1 | cairns
# Processing Record 636 of Set 1 | atherton
# Processing Record 637 of Set 1 | matara
# Processing Record 638 of Set 1 | kalabo
# Processing Record 639 of Set 1 | wuzhou
# Processing Record 640 of Set 1 | konevo
# Processing Record 641 of Set 1 | talnakh
# Processing Record 642 of Set 1 | andenes
# Processing Record 643 of Set 1 | borovoy
# Processing Record 644 of Set 1 | lufilufi
# Processing Record 645 of Set 1 | collie
# Processing Record 646 of Set 1 | chumphon
# Processing Record 647 of Set 1 | manbij
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_dict = {
    "City" : new_cities,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
}

city_dict

city_data = pd.DataFrame(city_dict)

# %%
len(city_data)
# Out:
# 584

# %%
# Export the city data into a .csv
city_data.to_csv(output_data_file)

# %%
# Diplay the DataFrame
city_data.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   saskylakh  71.9167  114.0833     33.75        87          94       10.11
# 1      loukhi  66.0764   33.0381     29.75        72         100        3.98
# 2     mataura -46.1927  168.8643     55.99        94          96       14.00
# 3  butaritari   3.0707  172.7902     82.85        73          94       10.00
# 4     ushuaia -54.8000  -68.3000     35.60        80          40       16.11
#
#   Country        Date
# 0      RU  1619674013
# 1      RU  1619674014
# 2      NZ  1619674014
# 3      KI  1619674015
# 4      AR  1619674015

# %%
city_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  584.000000  584.000000  584.000000  584.000000  584.000000  584.000000
# mean    20.342129   21.631711   62.610925   69.549658   56.760274    7.332945
# std     32.685240   87.195971   19.323612   23.331034   36.741003    4.765858
# min    -54.800000 -179.166700   15.930000    1.000000    0.000000    0.310000
# 25%     -6.266700  -51.693925   48.000000   60.000000   20.000000    3.560000
# 50%     23.972200   25.991650   66.585000   75.000000   68.500000    6.510000
# 75%     48.978875   98.792725   78.010000   87.000000   90.000000   10.110000
# max     78.218600  179.316700  105.960000  100.000000  100.000000   26.240000
#
#                Date
# count  5.840000e+02
# mean   1.619674e+09
# std    7.675726e+01
# min    1.619674e+09
# 25%    1.619674e+09
# 50%    1.619674e+09
# 75%    1.619674e+09
# max    1.619674e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
filtered_city_data = city_data.loc[city_data["Humidity"]<=100,:]
len(filtered_city_data)
# Out:
# 584

# %%
filtered_city_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  584.000000  584.000000  584.000000  584.000000  584.000000  584.000000
# mean    20.342129   21.631711   62.610925   69.549658   56.760274    7.332945
# std     32.685240   87.195971   19.323612   23.331034   36.741003    4.765858
# min    -54.800000 -179.166700   15.930000    1.000000    0.000000    0.310000
# 25%     -6.266700  -51.693925   48.000000   60.000000   20.000000    3.560000
# 50%     23.972200   25.991650   66.585000   75.000000   68.500000    6.510000
# 75%     48.978875   98.792725   78.010000   87.000000   90.000000   10.110000
# max     78.218600  179.316700  105.960000  100.000000  100.000000   26.240000
#
#                Date
# count  5.840000e+02
# mean   1.619674e+09
# std    7.675726e+01
# min    1.619674e+09
# 25%    1.619674e+09
# 50%    1.619674e+09
# 75%    1.619674e+09
# max    1.619674e+09

# %%
#  Get the indices of cities that have humidity over 100%.
humidity_over_100 = city_data.loc[city_data["Humidity"]>100,:]
indexes = humidity_over_100.index
indexes
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = city_data

# With this loop we can always make sure we drop the rows with humidity over 100 dynamically
for i in indexes:
    clean_city_data = city_data.drop(city_data.index[i], inplace = False)

clean_city_data.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   saskylakh  71.9167  114.0833     33.75        87          94       10.11
# 1      loukhi  66.0764   33.0381     29.75        72         100        3.98
# 2     mataura -46.1927  168.8643     55.99        94          96       14.00
# 3  butaritari   3.0707  172.7902     82.85        73          94       10.00
# 4     ushuaia -54.8000  -68.3000     35.60        80          40       16.11
#
#   Country        Date
# 0      RU  1619674013
# 1      RU  1619674014
# 2      NZ  1619674014
# 3      KI  1619674015
# 4      AR  1619674015

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Max Temp"]

## Add properties to the plot
plt.figure(figsize=(10,5))
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('City Latitude vs Max Temperature (28/04/2021)')
plt.grid()

## Create the Scatter plot and linear
plt.scatter(x_values,y_values, marker='o', color='#1d71ac', edgecolors='black')

plt.savefig("Images/lat_vs_max_temp.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Humidity"]

## Add properties to the plot
plt.figure(figsize=(10,5))
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs Humidity (28/04/2021)')
plt.grid()

## Create the Scatter plot and linear
plt.scatter(x_values,y_values, marker='o', color='#1d71ac', edgecolors='black')

plt.savefig("Images/lat_vs_humitidy.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Cloudiness"]

## Add properties to the plot
plt.figure(figsize=(10,5))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs Cloudiness (28/04/2021)')
plt.grid()

## Create the Scatter plot and linear
plt.scatter(x_values,y_values, marker='o', color='#1d71ac', edgecolors='black')

plt.savefig("Images/lat_vs_cloudiness.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Wind Speed"]

## Add properties to the plot
plt.figure(figsize=(10,5))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('City Latitude vs Wind Speed (28/04/2021)')
plt.grid()

## Create the Scatter plot and linear
plt.scatter(x_values,y_values, marker='o', color='#1d71ac', edgecolors='black')

plt.savefig("Images/lat_vs_wind_speed.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_hemisphere_data = clean_city_data.loc[clean_city_data["Lat"]>=0,:]
south_hemisphere_data = clean_city_data.loc[clean_city_data["Lat"]<0,:]

# %%
column = 'Max Temp'

# %%
x_values = north_hemisphere_data['Lat']
y_values = north_hemisphere_data[column]

correlation = st.pearsonr(x_values,y_values)

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

## Get the line equation
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

## Add properties to the plot
plt.figure(figsize=(10,5))
plt.xlabel('Latitude')
plt.ylabel(column)
plt.annotate(line_eq,(16,20),fontsize=15,color="red")
plt.grid()

## Create the Scatter plot and linear
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

## Print the calcuations
print("----------------------------------------------------------------------")
print(f"The correlation between both factors is {round(correlation[0],2)}")
print(line_eq)
print(f"The r-value is: {rvalue**2}")
print("----------------------------------------------------------------------")

plt.savefig("Images/nh_lat_vs_temp.png", bbox_inches = "tight")

## Show plot
plt.show()
# Out:
# ----------------------------------------------------------------------
# The correlation between both factors is -0.88
# y = -0.91x +93.95
# The r-value is: 0.768169948916639
# ----------------------------------------------------------------------

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south_hemisphere_data['Lat']
y_values = south_hemisphere_data['Max Temp']

correlation = st.pearsonr(x_values,y_values)

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

## Get the line equation
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

## Add properties to the plot
plt.figure(figsize=(10,5))
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_eq,(-50,90),fontsize=15,color="red")
plt.grid()

## Create the Scatter plot and linear
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

## Print the calcuations
print("----------------------------------------------------------------------")
print(f"The correlation between both factors is {round(correlation[0],2)}")
print(line_eq)
print(f"The r-value is: {rvalue**2}")
print("----------------------------------------------------------------------")

plt.savefig("Images/sh_lat_vs_temp.png", bbox_inches = "tight")
## Show plot
plt.show()
# Out:
# ----------------------------------------------------------------------
# The correlation between both factors is 0.61
# y = 0.49x +80.63
# The r-value is: 0.3661294040506635
# ----------------------------------------------------------------------

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
column = 'Humidity'

# %%
x_values = north_hemisphere_data['Lat']
y_values = north_hemisphere_data[column]

correlation = st.pearsonr(x_values,y_values)

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

## Get the line equation
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

## Add properties to the plot
plt.figure(figsize=(10,5))
plt.xlabel('Latitude')
plt.ylabel(column)
plt.annotate(line_eq,(50,10),fontsize=15,color="red")
plt.grid()

## Create the Scatter plot and linear
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

## Print the calcuations
print("----------------------------------------------------------------------")
print(f"The correlation between both factors is {round(correlation[0],2)}")
print(line_eq)
print(f"The r-value is: {rvalue**2}")
print("----------------------------------------------------------------------")

plt.savefig("Images/nh_lat_vs_hum.png", bbox_inches = "tight")
## Show plot
plt.show()
# Out:
# ----------------------------------------------------------------------
# The correlation between both factors is 0.14
# y = 0.18x +59.57
# The r-value is: 0.02018792839327438
# ----------------------------------------------------------------------

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south_hemisphere_data['Lat']
y_values = south_hemisphere_data[column]

correlation = st.pearsonr(x_values,y_values)

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

## Get the line equation
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

## Add properties to the plot
plt.figure(figsize=(10,5))
plt.xlabel('Latitude')
plt.ylabel(column)
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.grid()

## Create the Scatter plot and linear
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

## Print the calcuations
print("----------------------------------------------------------------------")
print(f"The correlation between both factors is {round(correlation[0],2)}")
print(line_eq)
print(f"The r-value is: {rvalue**2}")
print("----------------------------------------------------------------------")

plt.savefig("Images/sh_lat_vs_hum.png", bbox_inches = "tight")
## Show plot
plt.show()
# Out:
# ----------------------------------------------------------------------
# The correlation between both factors is 0.13
# y = 0.16x +79.54
# The r-value is: 0.015681469258231887
# ----------------------------------------------------------------------

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
column = 'Cloudiness'

# %%
x_values = north_hemisphere_data['Lat']
y_values = north_hemisphere_data[column]

correlation = st.pearsonr(x_values,y_values)

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

## Get the line equation
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

## Add properties to the plot
plt.figure(figsize=(10,5))
plt.xlabel('Latitude')
plt.ylabel(column)
plt.annotate(line_eq,(16,20),fontsize=15,color="red")
plt.grid()

## Create the Scatter plot and linear
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

## Print the calcuations
print("----------------------------------------------------------------------")
print(f"The correlation between both factors is {round(correlation[0],2)}")
print(line_eq)
print(f"The r-value is: {rvalue**2}")
print("----------------------------------------------------------------------")

plt.savefig("Images/nh_lat_vs_cloud.png", bbox_inches = "tight")
## Show plot
plt.show()
# Out:
# ----------------------------------------------------------------------
# The correlation between both factors is 0.01
# y = 0.03x +56.26
# The r-value is: 0.0002206639582555514
# ----------------------------------------------------------------------

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south_hemisphere_data['Lat']
y_values = south_hemisphere_data[column]

correlation = st.pearsonr(x_values,y_values)

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

## Get the line equation
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

## Add properties to the plot
plt.figure(figsize=(10,5))
plt.xlabel('Latitude')
plt.ylabel(column)
plt.annotate(line_eq,(16,20),fontsize=15,color="red")
plt.grid()

## Create the Scatter plot and linear
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

## Print the calcuations
print("----------------------------------------------------------------------")
print(f"The correlation between both factors is {round(correlation[0],2)}")
print(line_eq)
print(f"The r-value is: {rvalue**2}")
print("----------------------------------------------------------------------")

plt.savefig("Images/sh_lat_vs_cloud.png", bbox_inches = "tight")
## Show plot
plt.show()
# Out:
# ----------------------------------------------------------------------
# The correlation between both factors is 0.26
# y = 0.71x +69.28
# The r-value is: 0.06735859303288991
# ----------------------------------------------------------------------

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
column = 'Wind Speed'

# %%
x_values = north_hemisphere_data['Lat']
y_values = north_hemisphere_data[column]

correlation = st.pearsonr(x_values,y_values)

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

## Get the line equation
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

## Add properties to the plot
plt.figure(figsize=(10,5))
plt.xlabel('Latitude')
plt.ylabel(column)
plt.annotate(line_eq,(50,25),fontsize=15,color="red")
plt.grid()

## Create the Scatter plot and linear
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

## Print the calcuations
print("----------------------------------------------------------------------")
print(f"The correlation between both factors is {round(correlation[0],2)}")
print(line_eq)
print(f"The r-value is: {rvalue**2}")
print("----------------------------------------------------------------------")

plt.savefig("Images/nh_lat_vs_wind.png", bbox_inches = "tight")
## Show plot
plt.show()
# Out:
# ----------------------------------------------------------------------
# The correlation between both factors is 0.1
# y = 0.02x +6.63
# The r-value is: 0.010288515448589825
# ----------------------------------------------------------------------

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_hemisphere_data['Lat']
y_values = south_hemisphere_data[column]

correlation = st.pearsonr(x_values,y_values)

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

## Get the line equation
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

## Add properties to the plot
plt.figure(figsize=(10,5))
plt.xlabel('Latitude')
plt.ylabel(column)
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.grid()

## Create the Scatter plot and linear
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

## Print the calcuations
print("----------------------------------------------------------------------")
print(f"The correlation between both factors is {round(correlation[0],2)}")
print(line_eq)
print(f"The r-value is: {rvalue**2}")
print("----------------------------------------------------------------------")

plt.savefig("Images/sh_lat_vs_wind.png", bbox_inches = "tight")
## Show plot
plt.show()
# Out:
# ----------------------------------------------------------------------
# The correlation between both factors is -0.33
# y = -0.12x +4.47
# The r-value is: 0.10985280469962139
# ----------------------------------------------------------------------
